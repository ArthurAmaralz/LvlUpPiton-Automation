# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Envio automatizado de emails com anexos.
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior:
# https://wlasaascom-my.sharepoint.com/:x:/g/personal/arthur_lima_mmr-ti_com/EaikDQucUd1NopzTpcTcMz8B7AuDOD5qf2COhKnfpGom7A?e=stAeQV
#
# usando o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado

# %%
import pyautogui
import time
''' Usando esse comando você pode adaptar as posições de clicks para a sua resolução do monitor, 
que dificilmente sera a mesma que a minha'''

time.sleep(5)
pyautogui.position()
# Out:
# Point(x=649, y=1188)

# %%
import pyautogui
import pyperclip
import time

# Intervalo entre as ações do pyautogui
pyautogui.PAUSE = 1

# Passo 1: Entrar no sistema (no nosso caso, entrar no link)
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://wlasaascom-my.sharepoint.com/:x:/g/personal/arthur_lima_mmr-ti_com/EaikDQucUd1NopzTpcTcMz8B7AuDOD5qf2COhKnfpGom7A?e=stAeQV")
# o comando write não vai escrever alguns caracteres especiais, nesse caso optei por copiar e colar o link 
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(7)

# clicar en arquivo
pyautogui.click(x=184, y=422, clicks=1)
time.sleep(2)

# Passo 2: Fazer o download do relatório
pyautogui.click(x=87, y=825, clicks=1) # clica nos 3 pontinhos
pyautogui.click(x=128, y=1019, clicks=1) # clica em salvar como
pyautogui.click(x=472, y=979, clicks=1) # clica em baixar uma copia
time.sleep(5)

# %% [markdown]
# ### Lendo os arquivos baixados

# %%
# Passo 4: Calcular os indicadores
import pandas as pd

tabela = pd.read_excel(r"D:\arthu\Downloads\Vendas - Dez.xlsx")
display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# Calcular os indicadores da empresa

faturamento = tabela["Valor Final"].sum()
print(faturamento)
quantidade = tabela["Quantidade"].sum()
print(quantidade)
# p.s. as casas decimais irei colocar dentro do corpo do email
# Out:
# 2917311
# 15227

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %%
# Passo 5: Entrar no email
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(7)

# Passo 6: Enviar por e-mail o resultado
pyautogui.click(x=477, y=517)
time.sleep(4)

pyautogui.write("pythonimpressionador+diretoria@gmail.com")
pyautogui.press("tab") # seleciona o email
# escreve outro email
# tab
# escreve outro email
# tab
pyautogui.press("tab") # pula pro campo de assunto
pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey("ctrl", "v") # escrever o assunto
pyautogui.press("tab") #pular pro corpo do email

texto = f"""
Prezados, bom dia

O faturamento no dia de ontem: R$ {faturamento:,.2f}
A quantidade de produtos vendidos: {quantidade:,} unidades

Att
Arthur Amaral"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

# anexar um arquivo
arquivo = r'D:\arthu\Downloads\Vendas - Dez.xlsx'
pyautogui.click(x=2904, y=1946)
time.sleep(2)
pyperclip.copy(arquivo)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5)
# clicar no botão enviar

# apertar Ctrl Enter
pyautogui.hotkey("ctrl", "enter")

# %% [markdown]
# ### Ao invés de esperar alguns segundos eu quisesse reconhecer uma imagem na tela?

# %%
# Passo 1: Entrar no sistema (no nosso caso, entrar no link)
# Antes de executar, é necessario instalar o opencv
# !pip install opencv-python

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://wlasaascom-my.sharepoint.com/:x:/g/personal/arthur_lima_mmr-ti_com/EaikDQucUd1NopzTpcTcMz8B7AuDOD5qf2COhKnfpGom7A")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# A imagem precisa está dentro da mesmo diretorio do notebook jupter e em png 
while not pyautogui.locateOnScreen("imagem.png", confidence=0.9): # confidence para que a precisão não precise ser de 100% na imagem
    time.sleep(1)
    
# Passo 2: Navegar até o local do relatório e segue os demais passos da mesma forma
pyautogui.click(x=878, y=676, clicks=2)
